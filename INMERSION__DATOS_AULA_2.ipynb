# %% [markdown]
# <a href="https://colab.research.google.com/github/RenzoBejarano/InmersionAlura/blob/main/INMERSION__DATOS_AULA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clase 1
# ```
# # Inmersion de datos
# ```

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

inmueble = pd.read_csv('/content/drive/MyDrive/Imersion DAtos/inmuebles_bogota.csv')
inmueble.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmueble.shape
# Out:
# (9520, 8)

# %%
inmueble.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'banos':'Banos','Área':'Area'}
inmueble = inmueble.rename(columns=columnas)
inmueble.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 55    Apartamento             Apartamento en venta en Kennedy             2
# 7712  Apartamento         Apartamento en venta en El Castillo             3
# 7834  Apartamento            Apartamento en venta en Cedritos             1
# 7400  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 9327  Apartamento      Apartamento en venta en Barrios Unidos             2
# 8723  Apartamento            Apartamento en venta en Fontibón             3
# 7067  Apartamento        Apartamento en venta en Los Mártires             2
# 3491  Apartamento      Apartamento en venta en Ciudad Salitre             3
# 2767     Edificio                Edificio en venta en Kennedy            10
# 2564  Apartamento         Apartamento en venta en Chico Norte             1
#
#       Baños  Area              Barrio                                 UPZ  \
# 55        1    40             Kennedy                     Kennedy Central
# 7712      5   200         El Castillo                              Lucero
# 7834      1    40            Cedritos                             Usaquén
# 7400      1    52  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 9327      2    78      Barrios Unidos                           Los Andes
# 8723      2    64            Fontibón                            Fontibón
# 7067      1    40        Los Mártires                           La Sabana
# 3491      3    94      Ciudad Salitre             Ciudad Salitre Oriental
# 2767      3   360             Kennedy                     Kennedy Central
# 2564      1    68         Chico Norte  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 55      $ 185.000.000
# 7712  $ 1.900.000.000
# 7834    $ 270.000.000
# 7400    $ 158.000.000
# 9327    $ 375.000.000
# 8723    $ 210.000.000
# 7067    $ 199.000.000
# 3491    $ 570.000.000
# 2767  $ 2.300.000.000
# 2564    $ 743.710.000

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmueble.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Baños                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# inmueble.iloc[]

# %%
inmueble.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Baños  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmueble['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmueble['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmueble['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmueble.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmueble.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmueble.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmueble.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmueble[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Baños  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmueble.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
(inmueble.UPZ.value_counts())
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inmuebles_barrio = inmueble.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# DESAFIO
# 1. Promedio de Area de todos los inmuebles en los barrios en el dataSet.
# El top 10.
#
# 2. Consultar otros Datos Estadisticos, conteo, mediano, valores min y max.

# %%
promedios_por_barrio = inmueble.groupby('Barrio')['Area'].mean().reset_index()

# %%
promedios_por_barrio
# Out:
#                  Barrio        Area
# 0               Alameda   97.000000
# 1              Alhambra  190.411765
# 2           Andes Norte  124.857143
# 3        Antonio Nariño  163.062500
# 4             Barrancas   70.200000
# ..                  ...         ...
# 144         Villa Maria  207.153846
# 145   Villas De Granada   86.590909
# 146            Villemar   76.888889
# 147         Zona Franca   54.000000
# 148  Zona Noroccidental  135.785633
#
# [149 rows x 2 columns]

# %%
top_10_promedios = promedios_por_barrio.sort_values(by='Area', ascending=False).head(10)

# %%
top_10_promedios
# Out:
#                     Barrio         Area
# 92                 Modelia  4316.750000
# 83              Libertador   642.000000
# 11           Bosa Piamonte   400.000000
# 73             La Soledad    378.625000
# 114               Restrepo   336.500000
# 127          Santa Librada   328.000000
# 80              Las Ferias   320.000000
# 124              Santa Ana   309.375000
# 141               Veraguas   302.666667
# 7    Bellavista Occidental   286.200000

# %%
import matplotlib.pyplot as plt

# %%
top_10_promedios.plot(x='Barrio', y='Area', kind='bar', figsize=(10,6), legend=False)
plt.xlabel('Barrio')
plt.ylabel('Promedio Area (m²)')
plt.title('Top 10 Promedios de Area por Barrio')
plt.legend(['Area Promedio'], fontsize = 10)

# %%
inmueble.sample(5)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 5093  Apartamento  Apartamento en venta en Ciudad Bolívar             3
# 3042  Apartamento        Apartamento en venta en Cedritos             3
# 2427  Apartamento  Apartamento en venta en Antonio Nariño             4
# 2899  Apartamento        Apartamento en venta en Fontibón             3
# 5063         Casa            Casa en venta en Pontevedra              4
#
#       Baños  Area          Barrio  \
# 5093      2    56  Ciudad Bolívar
# 3042      2   104        Cedritos
# 2427      3   162  Antonio Nariño
# 2899      3   120        Fontibón
# 5063      3   267     Pontevedra
#
#                                                     UPZ            Valor
# 5093  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 162.000.000
# 3042                                            Usaquén    $ 367.500.000
# 2427                                           Restrepo    $ 390.000.000
# 2899                                           Fontibón    $ 600.000.000
# 5063                                        La Floresta  $ 1.100.000.000

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
type(inmueble.Valor[0])
# Out:
# str

# %%
inmueble.Valor[0]+inmueble.Valor[1]
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmueble.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmueble.Valor.str.split(expand=True)
inmueble['Moneda'] = valor[0]
inmueble['Precio'] = valor[1]
inmueble.sample(3)
# Out:
#              Tipo                         Descripcion  Habitaciones  Baños  \
# 6232         Casa            Casa en venta en Tintala             4      2
# 6655  Apartamento  Apartamento en venta en Cantagallo             2      2
# 2931  Apartamento        Apartamento en venta en Bosa             3      1
#
#       Area      Barrio           UPZ          Valor Moneda       Precio
# 6232    73     Tintala       Tintala  $ 203.000.000      $  203.000.000
# 6655    64  Cantagallo      Britalia  $ 387.000.000      $  387.000.000
# 2931    47        Bosa  Bosa Central  $ 134.000.000      $  134.000.000

# %%
inmueble['Precio'].sum()
# Out:
# %%
inmueble['Precio'] = inmueble['Precio'].str.replace('.','',regex=True)

# %%
inmueble[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmueble['Precio_Millon'] = inmueble.Precio.astype('float')/1000000
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmueble.describe()
# Out:
#        Habitaciones        Baños           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmueble.describe()
# Out:
#        Habitaciones   Baños      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmueble.loc[inmueble.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmueble['Precio_Millon'].plot.hist(bins=1000)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmueble, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de los Inmuebles en Bogotá')
plt.xlim((50,1000))
plt.ylim((0,20))
plt.show()

# %% [markdown]
# **DESAFIO**
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmueble (refinar el grafico: Titulos, aumentar el tamaño de lables, colores, conclusion de la informacion)
#
# 2. Precio del m2 por barrio y hacer el grafico mas adecuado para esta nueva variable. Ayuda(Precio/ metro cuadrado)
