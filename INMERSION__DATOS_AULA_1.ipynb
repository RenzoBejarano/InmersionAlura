# %% [markdown]
# <a href="https://colab.research.google.com/github/RenzoBejarano/InmersionAlura/blob/main/INMERSION__DATOS_AULA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clase 1
# ```
# # Inmersion de datos
# ```

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmueble = pd.read_csv('/content/drive/MyDrive/Imersion DAtos/inmuebles_bogota.csv')
inmueble.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmueble.shape
# Out:
# (9520, 8)

# %%
inmueble.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'banos':'Banos','Área':'Area'}
inmueble = inmueble.rename(columns=columnas)
inmueble.sample(10)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 5188  Apartamento       Apartamento en venta en Alhambra             2      2
# 1699        Local       Local en venta en Barrios Unidos            13      8
# 8143         Casa              Casa en venta en Fontibón             4      4
# 2068  Apartamento       Apartamento en venta en Cedritos             4      3
# 584   Apartamento       Apartamento en venta en Cedritos             2      2
# 7303  Apartamento       Apartamento en venta en Engativa             3      2
# 7093  Apartamento       Apartamento en venta en Fontibón             3      2
# 8931  Apartamento    Apartamento en venta en Los Rosales             3      4
# 8540  Apartamento  Apartamento en venta en Santa Barbara             2      2
# 3383         Casa              Casa en venta en Madelena             4      3
#
#       Area          Barrio                                    UPZ  \
# 5188   113        Alhambra                            La Alhambra
# 1699   130  Barrios Unidos                              Los Andes
# 8143   167        Fontibón                               Fontibón
# 2068   137        Cedritos                                Usaquén
# 584     70        Cedritos                                Usaquén
# 7303    70        Engativa                               Engativá
# 7093    58        Fontibón                               Fontibón
# 8931   240     Los Rosales     CHAPINERO: Chicó Lago + El Refugio
# 8540    83   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 3383   276        Madelena                           Arborizadora
#
#                 Valor
# 5188    $ 480.000.000
# 1699    $ 750.000.000
# 8143    $ 660.000.000
# 2068    $ 800.000.000
# 584     $ 319.000.000
# 7303    $ 298.500.000
# 7093    $ 270.000.000
# 8931  $ 2.317.500.000
# 8540    $ 420.000.000
# 3383    $ 780.000.000

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmueble.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# inmueble.iloc[]

# %%
inmueble.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmueble['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmueble['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmueble['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmueble.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmueble.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmueble.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmueble.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmueble[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmueble.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
(inmueble.UPZ.value_counts())
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inmuebles_barrio = inmueble.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# DESAFIO
# 1. Promedio de Area de todos los inmuebles en los barrios en el dataSet.
# El top 10.
#
# 2. Consultar otros Datos Estadisticos, conteo, mediano, valores min y max.

# %%
promedios_por_barrio = inmueble.groupby('Barrio')['Area'].mean().reset_index()

# %%
promedios_por_barrio
# Out:
#                  Barrio        Area
# 0               Alameda   97.000000
# 1              Alhambra  190.411765
# 2           Andes Norte  124.857143
# 3        Antonio Nariño  163.062500
# 4             Barrancas   70.200000
# ..                  ...         ...
# 144         Villa Maria  207.153846
# 145   Villas De Granada   86.590909
# 146            Villemar   76.888889
# 147         Zona Franca   54.000000
# 148  Zona Noroccidental  135.785633
#
# [149 rows x 2 columns]

# %%
top_10_promedios = promedios_por_barrio.sort_values(by='Area', ascending=False).head(10)

# %%
top_10_promedios
# Out:
#                     Barrio         Area
# 92                 Modelia  4316.750000
# 83              Libertador   642.000000
# 11           Bosa Piamonte   400.000000
# 73             La Soledad    378.625000
# 114               Restrepo   336.500000
# 127          Santa Librada   328.000000
# 80              Las Ferias   320.000000
# 124              Santa Ana   309.375000
# 141               Veraguas   302.666667
# 7    Bellavista Occidental   286.200000

# %%
import matplotlib.pyplot as plt

# %%
top_10_promedios.plot(x='Barrio', y='Area', kind='bar', figsize=(10,6), legend=False)
plt.xlabel('Barrio')
plt.ylabel('Promedio Area (m²)')
plt.title('Top 10 Promedios de Area por Barrio')
plt.legend(['Area Promedio'], fontsize = 10)
